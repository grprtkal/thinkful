# %%
# the number of bikes available every minute for an hour across all of New York City in order 
# to see which station or set of stations is the most active in New York City for that hour. 
# Activity is defined as the total number of bicycles taken out or returned in an hour.

# %% [markdown]
# <h6>Let's record the number of bikes available every minute for an hour across all of New York City</h6>

# %% [markdown]
# <p>Requests is a package that allows downloading of data from any online source.</p>

# %%
import requests
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3 as lite
import time
from dateutil.parser import parse 
import collections

# %matplotlib inline

# %%
r = requests.get("http://www.citibikenyc.com/stations/json")
r.json()
# Out:
# {u'executionTime': u'2015-09-27 02:52:26 AM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:06 AM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:19 AM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Franklin St & W Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 82,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:22 AM',
#    u'latitude': 40.71117416,
#    u'location': u'',
#    u'longitude': -74.00016545,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 38,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 83,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:06 AM',
#    u'latitude': 40.68382604,
#    u'location': u'',
#    u'longitude': -73.97632328,
#    u'postalCode': u'',
#    u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Atlantic Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 62},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 116,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:40 AM',
#    u'latitude': 40.74177603,
#    u'location': u'',
#    u'longitude': -74.00149746,
#    u'postalCode': u'',
#    u'stAddress1': u'W 17 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 17 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 119,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:36 AM',
#    u'latitude': 40.69608941,
#    u'location': u'',
#    u'longitude': -73.97803415,
#    u'postalCode': u'',
#    u'stAddress1': u'Park Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Park Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 120,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:00 AM',
#    u'latitude': 40.68676793,
#    u'location': u'',
#    u'longitude': -73.95928168,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 30,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 127,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:23 AM',
#    u'latitude': 40.73172428,
#    u'location': u'',
#    u'longitude': -74.00674436,
#    u'postalCode': u'',
#    u'stAddress1': u'Barrow St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Barrow St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 128,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-24 09:23:40 AM',
#    u'latitude': 40.72710258,
#    u'location': u'',
#    u'longitude': -74.00297088,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Prince St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 137,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:52 AM',
#    u'latitude': 40.761628,
#    u'location': u'',
#    u'longitude': -73.972924,
#    u'postalCode': u'',
#    u'stAddress1': u'E 56 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 56 St & Madison Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 46},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 143,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:08 AM',
#    u'latitude': 40.69239502,
#    u'location': u'',
#    u'longitude': -73.99337909,
#    u'postalCode': u'',
#    u'stAddress1': u'Clinton St & Joralemon St',
#    u'stAddress2': u'',
#    u'stationName': u'Clinton St & Joralemon St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 144,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:01 AM',
#    u'latitude': 40.69839895,
#    u'location': u'',
#    u'longitude': -73.98068914,
#    u'postalCode': u'',
#    u'stAddress1': u'Nassau St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Nassau St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 146,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:33 AM',
#    u'latitude': 40.71625008,
#    u'location': u'',
#    u'longitude': -74.0091059,
#    u'postalCode': u'',
#    u'stAddress1': u'Hudson St & Reade St',
#    u'stAddress2': u'',
#    u'stationName': u'Hudson St & Reade St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 147,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:04 AM',
#    u'latitude': 40.71542197,
#    u'location': u'',
#    u'longitude': -74.01121978,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Warren St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 150,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:25 AM',
#    u'latitude': 40.7208736,
#    u'location': u'',
#    u'longitude': -73.98085795,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue C',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue C',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 151,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:02 AM',
#    u'latitude': 40.7218158,
#    u'location': u'',
#    u'longitude': -73.99720307,
#    u'postalCode': u'',
#    u'stAddress1': u'Cleveland Pl & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Cleveland Pl & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 152,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:05 AM',
#    u'latitude': 40.71473993,
#    u'location': u'',
#    u'longitude': -74.00910627,
#    u'postalCode': u'',
#    u'stAddress1': u'Warren St & Church St',
#    u'stAddress2': u'',
#    u'stationName': u'Warren St & Church St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 53,
#    u'city': u'',
#    u'id': 153,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-09 03:19:40 PM',
#    u'latitude': 40.752062307,
#    u'location': u'',
#    u'longitude': -73.9816324043,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & 5 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 157,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:23 AM',
#    u'latitude': 40.69089272,
#    u'location': u'',
#    u'longitude': -73.99612349,
#    u'postalCode': u'',
#    u'stAddress1': u'Henry St & Atlantic Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Henry St & Atlantic Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 160,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:11 AM',
#    u'latitude': 40.748238,
#    u'location': u'',
#    u'longitude': -73.978311,
#    u'postalCode': u'',
#    u'stAddress1': u'E 37 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 37 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 161,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:30 AM',
#    u'latitude': 40.72917025,
#    u'location': u'',
#    u'longitude': -73.99810231,
#    u'postalCode': u'',
#    u'stAddress1': u'LaGuardia Pl & W 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'LaGuardia Pl & W 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 41,
#    u'city': u'',
#    u'id': 164,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:41 AM',
#    u'latitude': 40.75323098,
#    u'location': u'',
#    u'longitude': -73.97032517,
#    u'postalCode': u'',
#    u'stAddress1': u'E 47 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 47 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 39,
#    u'city': u'',
#    u'id': 167,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:17 AM',
#    u'latitude': 40.7489006,
#    u'location': u'',
#    u'longitude': -73.97604882,
#    u'postalCode': u'',
#    u'stAddress1': u'E 39 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 39 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 44,
#    u'city': u'',
#    u'id': 168,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:14 AM',
#    u'latitude': 40.73971301,
#    u'location': u'',
#    u'longitude': -73.99456405,
#    u'postalCode': u'',
#    u'stAddress1': u'W 18 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 18 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 46,
#    u'city': u'',
#    u'id': 173,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:27 AM',
#    u'latitude': 40.76064679,
#    u'location': u'',
#    u'longitude': -73.98442659,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 49 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 49 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 51},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 174,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:23 AM',
#    u'latitude': 40.7381765,
#    u'location': u'',
#    u'longitude': -73.97738662,
#    u'postalCode': u'',
#    u'stAddress1': u'E 25 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 25 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 45,
#    u'city': u'',
#    u'id': 195,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-18 07:55:14 AM',
#    u'latitude': 40.70905623,
#    u'location': u'',
#    u'longitude': -74.01043382,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty St & Broadway',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:01 AM',
#    u'latitude': 40.74334935,
#    u'location': u'',
#    u'longitude': -74.00681753,
#    u'postalCode': u'',
#    u'stAddress1': u'W 16 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 16 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 28},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:15 AM',
#    u'latitude': 40.70037867,
#    u'location': u'',
#    u'longitude': -73.99548059,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Heights & Cranberry St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Heights & Cranberry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:13 AM',
#    u'latitude': 40.70277159,
#    u'location': u'',
#    u'longitude': -73.99383605,
#    u'postalCode': u'',
#    u'stAddress1': u'Old Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Old Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 218,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:27 AM',
#    u'latitude': 40.69028437,
#    u'location': u'',
#    u'longitude': -73.98707105,
#    u'postalCode': u'',
#    u'stAddress1': u'Gallatin Pl & Livingston St',
#    u'stAddress2': u'',
#    u'stationName': u'Gallatin Pl & Livingston St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:49 AM',
#    u'latitude': 40.73781509,
#    u'location': u'',
#    u'longitude': -73.99994661,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 7 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 7 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:16 AM',
#    u'latitude': 40.71146364,
#    u'location': u'',
#    u'longitude': -74.00552427,
#    u'postalCode': u'',
#    u'stAddress1': u'Spruce St & Nassau St',
#    u'stAddress2': u'',
#    u'stationName': u'Spruce St & Nassau St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:03 AM',
#    u'latitude': 40.74195138,
#    u'location': u'',
#    u'longitude': -74.00803013,
#    u'postalCode': u'',
#    u'stAddress1': u'W 14 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 14 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 48,
#    u'city': u'',
#    u'id': 228,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:33 AM',
#    u'latitude': 40.7546011026,
#    u'location': u'',
#    u'longitude': -73.971878855,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:37 AM',
#    u'latitude': 40.72743423,
#    u'location': u'',
#    u'longitude': -73.99379025,
#    u'postalCode': u'',
#    u'stAddress1': u'Great Jones St',
#    u'stAddress2': u'',
#    u'stationName': u'Great Jones St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 232,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:11 AM',
#    u'latitude': 40.69597683,
#    u'location': u'',
#    u'longitude': -73.99014892,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza E & Tillary St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza E & Tillary St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 233,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:55 AM',
#    u'latitude': 40.694757013639,
#    u'location': u'',
#    u'longitude': -73.990527391434,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza W & Pierrepont St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza W & Pierrepont St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 38},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 236,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:32 AM',
#    u'latitude': 40.7284186,
#    u'location': u'',
#    u'longitude': -73.98713956,
#    u'postalCode': u'',
#    u'stAddress1': u'St Marks Pl & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'St Marks Pl & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 37,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 237,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:45 AM',
#    u'latitude': 40.73047309,
#    u'location': u'',
#    u'longitude': -73.98672378,
#    u'postalCode': u'',
#    u'stAddress1': u'E 11 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 11 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 238,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:14 AM',
#    u'latitude': 40.7361967,
#    u'location': u'',
#    u'longitude': -74.00859207,
#    u'postalCode': u'',
#    u'stAddress1': u'Bank St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Bank St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 239,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:36 AM',
#    u'latitude': 40.69196566,
#    u'location': u'',
#    u'longitude': -73.9813018,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby St & Fleet St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby St & Fleet St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 241,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:28 AM',
#    u'latitude': 40.68981035,
#    u'location': u'',
#    u'longitude': -73.97493121,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & S Portland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & S Portland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 242,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:13 AM',
#    u'latitude': 40.697787,
#    u'location': u'',
#    u'longitude': -73.973736,
#    u'postalCode': u'',
#    u'stAddress1': u'Carlton Ave & Flushing Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Carlton Ave & Flushing Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 243,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:33 AM',
#    u'latitude': 40.688226,
#    u'location': u'',
#    u'longitude': -73.979382,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Rockwell Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Rockwell Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 244,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:00 AM',
#    u'latitude': 40.69196035,
#    u'location': u'',
#    u'longitude': -73.96536851,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby Ave & Hall St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby Ave & Hall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 245,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:01 AM',
#    u'latitude': 40.69327018,
#    u'location': u'',
#    u'longitude': -73.97703874,
#    u'postalCode': u'',
#    u'stAddress1': u'Myrtle Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Myrtle Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 247,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:44 AM',
#    u'latitude': 40.73535398,
#    u'location': u'',
#    u'longitude': -74.00483091,
#    u'postalCode': u'',
#    u'stAddress1': u'Perry St & Bleecker St',
#    u'stAddress2': u'',
#    u'stationName': u'Perry St & Bleecker St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 248,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:06 AM',
#    u'latitude': 40.72185379,
#    u'location': u'',
#    u'longitude': -74.00771779,
#    u'postalCode': u'',
#    u'stAddress1': u'Laight St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Laight St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 249,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:28 AM',
#    u'latitude': 40.71870987,
#    u'location': u'',
#    u'longitude': -74.0090009,
#    u'postalCode': u'',
#    u'stAddress1': u'Harrison St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Harrison St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 250,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:24 AM',
#    u'latitude': 40.72456089,
#    u'location': u'',
#    u'longitude': -73.99565293,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & Jersey St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & Jersey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 40},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 251,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:19 AM',
#    u'latitude': 40.72317958,
#    u'location': u'',
#    u'longitude': -73.99480012,
#    u'postalCode': u'',
#    u'stAddress1': u'Mott St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'Mott St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 252,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:31 AM',
#    u'latitude': 40.73226398,
#    u'location': u'',
#    u'longitude': -73.99852205,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Washington Sq',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Washington Sq',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 253,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:38 AM',
#    u'latitude': 40.73543934,
#    u'location': u'',
#    u'longitude': -73.99453948,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 254,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:32 AM',
#    u'latitude': 40.73532427,
#    u'location': u'',
#    u'longitude': -73.99800419,
#    u'postalCode': u'',
#    u'stAddress1': u'W 11 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 11 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 257,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:44 AM',
#    u'latitude': 40.71939226,
#    u'location': u'',
#    u'longitude': -74.00247214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lispenard St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Lispenard St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 258,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:03 AM',
#    u'latitude': 40.68940747,
#    u'location': u'',
#    u'longitude': -73.96885458,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 37,
#    u'city': u'',
#    u'id': 259,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:26 AM',
#    u'latitude': 40.70122128,
#    u'location': u'',
#    u'longitude': -74.01234218,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Whitehall St',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Whitehall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 260,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:34 AM',
#    u'latitude': 40.70365182,
#    u'location': u'',
#    u'longitude': -74.01167797,
#    u'postalCode': u'',
#    u'stAddress1': u'Broad St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Broad St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 261,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:02 AM',
#    u'latitude': 40.69474881,
#    u'location': u'',
#    u'longitude': -73.98362464,
#    u'postalCode': u'',
#    u'stAddress1': u'Johnson St & Gold St',
#    u'stAddress2': u'',
#    u'stationName': u'Johnson St & Gold St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 262,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:52 AM',
#    u'latitude': 40.6917823,
#    u'location': u'',
#    u'longitude': -73.9737299,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Park',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 263,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:35 AM',
#    u'latitude': 40.71729,
#    u'location': u'',
#    u'longitude': -73.996375,
#    u'postalCode': u'',
#    u'stAddress1': u'Elizabeth St & Hester St',
#    u'stAddress2': u'',
#    u'stationName': u'Elizabeth St & Hester St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 264,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:08 AM',
#    u'latitude': 40.70706456,
#    u'location': u'',
#    u'longitude': -74.00731853,
#    u'postalCode': u'',
#    u'stAddress1': u'Maiden Ln & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'Maiden Ln & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 265,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:48 AM',
#    u'latitude': 40.72229346,
#    u'location': u'',
#    u'longitude': -73.99147535,
#    u'postalCode': u'',
#    u'stAddress1': u'Stanton St & Chrystie St',
#    u'stAddress2': u'',
#    u'stationName': u'Stanton St & Chrystie St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 266,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:14 AM',
#    u'latitude': 40.72368361,
#    u'location': u'',
#    u'longitude': -73.97574813,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 45,
#    u'city': u'',
#    u'id': 267,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:13 AM',
#    u'latitude': 40.75097711,
#    u'location': u'',
#    u'longitude': -73.98765428,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 36 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 36 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 268,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:48 AM',
#    u'latitude': 40.71910537,
#    u'location': u'',
#    u'longitude': -73.99973337,
#    u'postalCode': u'',
#    u'stAddress1': u'Howard St & Centre St',
#    u'stAddress2': u'',
#    u'stationName': u'Howard St & Centre St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 270,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:15 AM',
#    u'latitude': 40.69308257,
#    u'location': u'',
#    u'longitude': -73.97178913,
#    u'postalCode': u'',
#    u'stAddress1': u'Adelphi St & Myrtle Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Adelphi St & Myrtle Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 274,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:41 AM',
#    u'latitude': 40.68691865,
#    u'location': u'',
#    u'longitude': -73.976682,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 275,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:09 AM',
#    u'latitude': 40.68650065,
#    u'location': u'',
#    u'longitude': -73.96563307,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Greene Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Greene Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 276,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:25 AM',
#    u'latitude': 40.71748752,
#    u'location': u'',
#    u'longitude': -74.0104554,
#    u'postalCode': u'',
#    u'stAddress1': u'Duane St & Greenwich St',
#    u'stAddress2': u'',
#    u'stationName': u'Duane St & Greenwich St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 278,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:02 AM',
#    u'latitude': 40.69766564,
#    u'location': u'',
#    u'longitude': -73.98476437,
#    u'postalCode': u'',
#    u'stAddress1': u'Concord St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Concord St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 32,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 279,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:28 AM',
#    u'latitude': 40.707873,
#    u'location': u'',
#    u'longitude': -74.00167,
#    u'postalCode': u'',
#    u'stAddress1': u'Peck Slip & Front St',
#    u'stAddress2': u'',
#    u'stationName': u'Peck Slip & Front St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 280,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:19 AM',
#    u'latitude': 40.73331967,
#    u'location': u'',
#    u'longitude': -73.99510132,
#    u'postalCode': u'',
#    u'stAddress1': u'E 10 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 10 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 59,
#    u'city': u'',
#    u'id': 281,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:05 AM',
#    u'latitude': 40.7643971,
#    u'location': u'',
#    u'longitude': -73.97371465,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand Army Plaza & Central Park S',
#    u'stAddress2': u'',
#    u'stationName': u'Grand Army Plaza & Central Park S',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 282,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:47 AM',
#    u'latitude': 40.70827295,
#    u'location': u'',
#    u'longitude': -73.96834101,
#    u'postalCode': u'',
#    u'stAddress1': u'Kent Ave & S 11 St',
#    u'stAddress2': u'',
#    u'stationName': u'Kent Ave & S 11 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 39,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 284,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:31 AM',
#    u'latitude': 40.7390169121,
#    u'location': u'',
#    u'longitude': -74.0026376103,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich Ave & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich Ave & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 285,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:46 AM',
#    u'latitude': 40.73454567,
#    u'location': u'',
#    u'longitude': -73.99074142,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & E 14 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & E 14 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 289,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:47 AM',
#    u'latitude': 40.6845683,
#    u'location': u'',
#    u'longitude': -73.95881081,
#    u'postalCode': u'',
#    u'stAddress1': u'Monroe St & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Monroe St & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 290,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:09 AM',
#    u'latitude': 40.76020258,
#    u'location': u'',
#    u'longitude': -73.96478473,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave & E 58 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave & E 58 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 291,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:25 AM',
#    u'latitude': 40.713126,
#    u'location': u'',
#    u'longitude': -73.984844,
#    u'postalCode': u'',
#    u'stAddress1': u'Madison St & Montgomery St',
#    u'stAddress2': u'',
#    u'stationName': u'Madison St & Montgomery St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 293,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:46 AM',
#    u'latitude': 40.73028666,
#    u'location': u'',
#    u'longitude': -73.9907647,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 294,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:47 AM',
#    u'latitude': 40.73049393,
#    u'location': u'',
#    u'longitude': -73.9957214,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Square E',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Square E',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 295,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:36 AM',
#    u'latitude': 40.71406667,
#    u'location': u'',
#    u'longitude': -73.99293911,
#    u'postalCode': u'',
#    u'stAddress1': u'Pike St & E Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Pike St & E Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 296,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:20 AM',
#    u'latitude': 40.71413089,
#    u'location': u'',
#    u'longitude': -73.9970468,
#    u'postalCode': u'',
#    u'stAddress1': u'Division St & Bowery',
#    u'stAddress2': u'',
#    u'stationName': u'Division St & Bowery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 297,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:33 AM',
#    u'latitude': 40.734232,
#    u'location': u'',
#    u'longitude': -73.986923,
#    u'postalCode': u'',
#    u'stAddress1': u'E 15 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 15 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 298,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:59 AM',
#    u'latitude': 40.68683208,
#    u'location': u'',
#    u'longitude': -73.9796772,
#    u'postalCode': u'',
#    u'stAddress1': u'3 Ave & Schermerhorn St',
#    u'stAddress2': u'',
#    u'stationName': u'3 Ave & Schermerhorn St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 40,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 300,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:03 AM',
#    u'latitude': 40.728145,
#    u'location': u'',
#    u'longitude': -73.990214,
#    u'postalCode': u'',
#    u'stAddress1': u'Shevchenko Pl & E 7 St',
#    u'stAddress2': u'',
#    u'stationName': u'Shevchenko Pl & E 7 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 33,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 301,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:47 AM',
#    u'latitude': 40.72217444,
#    u'location': u'',
#    u'longitude': -73.98368779,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 302,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:56 AM',
#    u'latitude': 40.72082834,
#    u'location': u'',
#    u'longitude': -73.97793172,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 303,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:59 AM',
#    u'latitude': 40.72362738,
#    u'location': u'',
#    u'longitude': -73.99949601,
#    u'postalCode': u'',
#    u'stAddress1': u'Mercer St & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Mercer St & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 304,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:43 AM',
#    u'latitude': 40.70463334,
#    u'location': u'',
#    u'longitude': -74.01361706,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & Battery Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & Battery Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 305,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:38 AM',
#    u'latitude': 40.76095756,
#    u'location': u'',
#    u'longitude': -73.96724467,
#    u'postalCode': u'',
#    u'stAddress1': u'E 58 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 58 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 32},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 306,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:02 AM',
#    u'latitude': 40.70823502,
#    u'location': u'',
#    u'longitude': -74.00530063,
#    u'postalCode': u'',
#    u'stAddress1': u'Cliff St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Cliff St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 307,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:22 AM',
#    u'latitude': 40.71427487,
#    u'location': u'',
#    u'longitude': -73.98990025,
#    u'postalCode': u'',
#    u'stAddress1': u'Canal St & Rutgers St',
#    u'stAddress2': u'',
#    u'stationName': u'Canal St & Rutgers St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 308,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:05 AM',
#    u'latitude': 40.71307916,
#    u'location': u'',
#    u'longitude': -73.99851193,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Oliver St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Oliver St',
# ...
#    u'lastCommunicationTime': u'2015-09-27 02:51:13 AM',
#    u'latitude': 40.7112423,
#    u'location': u'',
#    u'longitude': -74.0557013,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty Light Rail',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty Light Rail',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 3193,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:50 AM',
#    u'latitude': 40.7244188,
#    u'location': u'',
#    u'longitude': -74.0780383,
#    u'postalCode': u'',
#    u'stAddress1': u'Lincoln Park',
#    u'stAddress2': u'',
#    u'stationName': u'Lincoln Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 3194,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:27 AM',
#    u'latitude': 40.7256033,
#    u'location': u'',
#    u'longitude': -74.06763,
#    u'postalCode': u'',
#    u'stAddress1': u'McGinley Square',
#    u'stAddress2': u'',
#    u'stationName': u'McGinley Square',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 3195,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:07 AM',
#    u'latitude': 40.7309459,
#    u'location': u'',
#    u'longitude': -74.0638906,
#    u'postalCode': u'',
#    u'stAddress1': u'Sip Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Sip Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 34},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3196,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:16 AM',
#    u'latitude': 40.7443187,
#    u'location': u'',
#    u'longitude': -74.0439909,
#    u'postalCode': u'',
#    u'stAddress1': u'Riverview Park',
#    u'stAddress2': u'',
#    u'stationName': u'Riverview Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 3197,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:17 AM',
#    u'latitude': 40.752559,
#    u'location': u'',
#    u'longitude': -74.044725,
#    u'postalCode': u'',
#    u'stAddress1': u'North St',
#    u'stAddress2': u'',
#    u'stationName': u'North St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3198,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:11 AM',
#    u'latitude': 40.7485362,
#    u'location': u'',
#    u'longitude': -74.0403131,
#    u'postalCode': u'',
#    u'stAddress1': u'Heights Elevator',
#    u'stAddress2': u'',
#    u'stationName': u'Heights Elevator',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3199,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:17 AM',
#    u'latitude': 40.7287448,
#    u'location': u'',
#    u'longitude': -74.0321082,
#    u'postalCode': u'',
#    u'stAddress1': u'Newport Pkwy',
#    u'stAddress2': u'',
#    u'stationName': u'Newport Pkwy',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 3200,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 01:13:59 AM',
#    u'latitude': 40.7111305,
#    u'location': u'',
#    u'longitude': -74.0788855,
#    u'postalCode': u'',
#    u'stAddress1': u'MLK Light Rail',
#    u'stAddress2': u'',
#    u'stationName': u'MLK Light Rail',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 3201,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:06 AM',
#    u'latitude': 40.737711,
#    u'location': u'',
#    u'longitude': -74.066921,
#    u'postalCode': u'',
#    u'stAddress1': u'Dey St',
#    u'stAddress2': u'',
#    u'stationName': u'Dey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 3202,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:06 AM',
#    u'latitude': 40.7272235,
#    u'location': u'',
#    u'longitude': -74.0337589,
#    u'postalCode': u'',
#    u'stAddress1': u'Newport PATH',
#    u'stAddress2': u'',
#    u'stationName': u'Newport PATH',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 3203,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:57 AM',
#    u'latitude': 40.727595966,
#    u'location': u'',
#    u'longitude': -74.044247311,
#    u'postalCode': u'',
#    u'stAddress1': u'Hamilton Park',
#    u'stAddress2': u'',
#    u'stationName': u'Hamilton Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 3205,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:19 AM',
#    u'latitude': 40.7165271,
#    u'location': u'',
#    u'longitude': -74.049425,
#    u'postalCode': u'',
#    u'stAddress1': u'JC Medical Center',
#    u'stAddress2': u'',
#    u'stationName': u'JC Medical Center',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 3206,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:42 AM',
#    u'latitude': 40.7311689,
#    u'location': u'',
#    u'longitude': -74.0575736,
#    u'postalCode': u'',
#    u'stAddress1': u'Hilltop',
#    u'stAddress2': u'',
#    u'stationName': u'Hilltop',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3207,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:49 AM',
#    u'latitude': 40.7376037,
#    u'location': u'',
#    u'longitude': -74.0524783,
#    u'postalCode': u'',
#    u'stAddress1': u'Oakland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Oakland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 3209,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:38 AM',
#    u'latitude': 40.7241765,
#    u'location': u'',
#    u'longitude': -74.0506564,
#    u'postalCode': u'',
#    u'stAddress1': u'Brunswick St',
#    u'stAddress2': u'',
#    u'stationName': u'Brunswick St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 3210,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:00 AM',
#    u'latitude': 40.742677141,
#    u'location': u'',
#    u'longitude': -74.051788633,
#    u'postalCode': u'',
#    u'stAddress1': u'Pershing Field',
#    u'stAddress2': u'',
#    u'stationName': u'Pershing Field',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3211,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:14 AM',
#    u'latitude': 40.72152515,
#    u'location': u'',
#    u'longitude': -74.046304543,
#    u'postalCode': u'',
#    u'stAddress1': u'Newark Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Newark Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:34 AM',
#    u'latitude': 40.734785818,
#    u'location': u'',
#    u'longitude': -74.050443636,
#    u'postalCode': u'',
#    u'stAddress1': u'Christ Hospital',
#    u'stAddress2': u'',
#    u'stationName': u'Christ Hospital',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3213,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:52 AM',
#    u'latitude': 40.71848892,
#    u'location': u'',
#    u'longitude': -74.047726625,
#    u'postalCode': u'',
#    u'stAddress1': u'Van Vorst Park',
#    u'stAddress2': u'',
#    u'stationName': u'Van Vorst Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 3214,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:15 AM',
#    u'latitude': 40.7127742,
#    u'location': u'',
#    u'longitude': -74.0364857,
#    u'postalCode': u'',
#    u'stAddress1': u'Essex Light Rail',
#    u'stAddress2': u'',
#    u'stationName': u'Essex Light Rail',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3215,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:48:47 AM',
#    u'latitude': 40.7467299,
#    u'location': u'',
#    u'longitude': -74.0492509,
#    u'postalCode': u'',
#    u'stAddress1': u'Central Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Central Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:07 AM',
#    u'latitude': 40.6970299,
#    u'location': u'',
#    u'longitude': -74.0969366,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Park',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 3217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:06 AM',
#    u'latitude': 40.698650544,
#    u'location': u'',
#    u'longitude': -74.082079678,
#    u'postalCode': u'',
#    u'stAddress1': u'Bayside Park',
#    u'stAddress2': u'',
#    u'stationName': u'Bayside Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3220,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:51:38 AM',
#    u'latitude': 40.7355311,
#    u'location': u'',
#    u'longitude': -74.063365,
#    u'postalCode': u'',
#    u'stAddress1': u'5 Corners Library',
#    u'stAddress2': u'',
#    u'stationName': u'5 Corners Library',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 3221,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:16 AM',
#    u'latitude': 40.743,
#    u'location': u'',
#    u'longitude': -73.93561,
#    u'postalCode': u'',
#    u'stAddress1': u'47 Ave & 31 St',
#    u'stAddress2': u'',
#    u'stationName': u'47 Ave & 31 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3222,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:32 AM',
#    u'latitude': 40.685159599892,
#    u'location': u'',
#    u'longitude': -73.97711366415,
#    u'postalCode': u'',
#    u'stAddress1': u'Hanson Pl & St Felix St',
#    u'stAddress2': u'',
#    u'stationName': u'Hanson Pl & St Felix St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 53,
#    u'city': u'',
#    u'id': 3223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:52:12 AM',
#    u'latitude': 40.758996559605,
#    u'location': u'',
#    u'longitude': -73.968653976917,
#    u'postalCode': u'',
#    u'stAddress1': u'E 55 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 55 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 3224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:31 AM',
#    u'latitude': 40.739973541034,
#    u'location': u'',
#    u'longitude': -74.005138725042,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 3225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:50:03 AM',
#    u'latitude': 40.7236589,
#    u'location': u'',
#    u'longitude': -74.0641943,
#    u'postalCode': u'',
#    u'stAddress1': u'Baldwin at Montgomery',
#    u'stAddress2': u'',
#    u'stationName': u'Baldwin at Montgomery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 14},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3226,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'1969-12-31 07:00:00 PM',
#    u'latitude': 40.78275,
#    u'location': u'',
#    u'longitude': -73.97137,
#    u'postalCode': u'',
#    u'stAddress1': u'Coming soon: W 82 St & Central Park West',
#    u'stAddress2': u'',
#    u'stationName': u'Coming soon: W 82 St & Central Park West',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'1969-12-31 07:00:00 PM',
#    u'latitude': 40.680617684555,
#    u'location': u'',
#    u'longitude': -73.946249485016,
#    u'postalCode': u'',
#    u'stAddress1': u'Marcy Ave & MacDonough St',
#    u'stAddress2': u'',
#    u'stationName': u'Marcy Ave & MacDonough St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 3231,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2015-09-27 02:49:45 AM',
#    u'latitude': 40.767800801481,
#    u'location': u'',
#    u'longitude': -73.965920805931,
#    u'postalCode': u'',
#    u'stAddress1': u'E 67 St & Park Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 67 St & Park Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59}]}

# %%
r.json().keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %%
# number of docks

len(r.json()['stationBeanList'])
# Out:
# 509

# %%
# unique list of keys for each station listing

key_list = [] 
for station in r.json()['stationBeanList']:
    for k in station.keys():
        if k not in key_list:
            key_list.append(k)
print(key_list)
# Out:
# [u'availableDocks', u'totalDocks', u'city', u'altitude', u'stAddress2', u'longitude', u'lastCommunicationTime', u'postalCode', u'statusValue', u'testStation', u'stAddress1', u'stationName', u'landMark', u'latitude', u'statusKey', u'availableBikes', u'id', u'location']

# %%
df = json_normalize(r.json()['stationBeanList'])
print(df)
# Out:
#     altitude  availableBikes  availableDocks city    id landMark  \
# 0                         24              15         72
# 1                          9              23         79
# 2                          7              19         82
# 3                         38              24         83
# 4                         14              22        116
# 5                         11               6        119
# 6                          7              12        120
# 7                         30               0        127
# 8                          0              29        128
# 9                          0              46        137
# 10                        10              14        143
# 11                         7              11        144
# 12                         5              34        146
# 13                        17              12        147
# 14                        14              17        150
# 15                        13              12        151
# 16                         0              28        152
# 17                         0              53        153
# 18                        13              10        157
# 19                        10              15        160
# 20                        22              11        161
# 21                         4              41        164
# 22                         5              39        167
# 23                         1              44        168
# 24                         3              46        173
# 25                         8              22        174
# 26                         0              45        195
# 27                        17              10        212
# 28                         3              20        216
# 29                         8              31        217
# ..       ...             ...             ...  ...   ...      ...
# 479                        0              32       3195
# 480                        6              10       3196
# 481                        6              12       3197
# 482                        5              13       3198
# 483                        8               5       3199
# 484                        9               9       3200
# 485                        4              14       3201
# 486                        0              18       3202
# 487                       17               9       3203
# 488                       11              11       3205
# 489                        9              14       3206
# 490                        6               8       3207
# 491                       10               6       3209
# 492                        9               9       3210
# 493                        3              19       3211
# 494                        6              15       3212
# 495                       12              10       3213
# 496                       11              11       3214
# 497                        8               8       3215
# 498                        7              10       3216
# 499                        5              12       3217
# 500                       10               8       3220
# 501                       15              12       3221
# 502                       20              19       3222
# 503                        1              53       3223
# 504                       16              20       3224
# 505                       11               3       3225
# 506                        0               0       3226
# 507                        0               0       3229
# 508                       36              21       3231
#
#       lastCommunicationTime   latitude location  longitude postalCode  \
# 0    2015-09-27 02:49:06 AM  40.767272          -73.993929
# 1    2015-09-27 02:51:19 AM  40.719116          -74.006667
# 2    2015-09-27 02:51:22 AM  40.711174          -74.000165
# 3    2015-09-27 02:50:06 AM  40.683826          -73.976323
# 4    2015-09-27 02:51:40 AM  40.741776          -74.001497
# 5    2015-09-27 02:50:36 AM  40.696089          -73.978034
# 6    2015-09-27 02:50:00 AM  40.686768          -73.959282
# 7    2015-09-27 02:50:23 AM  40.731724          -74.006744
# 8    2015-09-24 09:23:40 AM  40.727103          -74.002971
# 9    2015-09-27 02:48:52 AM  40.761628          -73.972924
# 10   2015-09-27 02:49:08 AM  40.692395          -73.993379
# 11   2015-09-27 02:52:01 AM  40.698399          -73.980689
# 12   2015-09-27 02:51:33 AM  40.716250          -74.009106
# 13   2015-09-27 02:49:04 AM  40.715422          -74.011220
# 14   2015-09-27 02:52:25 AM  40.720874          -73.980858
# 15   2015-09-27 02:51:02 AM  40.721816          -73.997203
# 16   2015-09-27 02:49:05 AM  40.714740          -74.009106
# 17   2015-09-09 03:19:40 PM  40.752062          -73.981632
# 18   2015-09-27 02:51:23 AM  40.690893          -73.996123
# 19   2015-09-27 02:52:11 AM  40.748238          -73.978311
# 20   2015-09-27 02:49:30 AM  40.729170          -73.998102
# 21   2015-09-27 02:50:41 AM  40.753231          -73.970325
# 22   2015-09-27 02:52:17 AM  40.748901          -73.976049
# 23   2015-09-27 02:49:14 AM  40.739713          -73.994564
# 24   2015-09-27 02:49:27 AM  40.760647          -73.984427
# 25   2015-09-27 02:49:23 AM  40.738177          -73.977387
# 26   2015-09-18 07:55:14 AM  40.709056          -74.010434
# 27   2015-09-27 02:50:01 AM  40.743349          -74.006818
# 28   2015-09-27 02:50:15 AM  40.700379          -73.995481
# 29   2015-09-27 02:49:13 AM  40.702772          -73.993836
# ..                      ...        ...      ...        ...        ...
# 479  2015-09-27 02:52:07 AM  40.730946          -74.063891
# 480  2015-09-27 02:50:16 AM  40.744319          -74.043991
# 481  2015-09-27 02:51:17 AM  40.752559          -74.044725
# 482  2015-09-27 02:51:11 AM  40.748536          -74.040313
# 483  2015-09-27 02:51:17 AM  40.728745          -74.032108
# 484  2015-09-27 01:13:59 AM  40.711131          -74.078885
# 485  2015-09-27 02:51:06 AM  40.737711          -74.066921
# 486  2015-09-27 02:49:06 AM  40.727224          -74.033759
# 487  2015-09-27 02:50:57 AM  40.727596          -74.044247
# 488  2015-09-27 02:49:19 AM  40.716527          -74.049425
# 489  2015-09-27 02:50:42 AM  40.731169          -74.057574
# 490  2015-09-27 02:49:49 AM  40.737604          -74.052478
# 491  2015-09-27 02:49:38 AM  40.724176          -74.050656
# 492  2015-09-27 02:49:00 AM  40.742677          -74.051789
# 493  2015-09-27 02:49:14 AM  40.721525          -74.046305
# 494  2015-09-27 02:50:34 AM  40.734786          -74.050444
# 495  2015-09-27 02:48:52 AM  40.718489          -74.047727
# 496  2015-09-27 02:52:15 AM  40.712774          -74.036486
# 497  2015-09-27 02:48:47 AM  40.746730          -74.049251
# 498  2015-09-27 02:49:07 AM  40.697030          -74.096937
# 499  2015-09-27 02:51:06 AM  40.698651          -74.082080
# 500  2015-09-27 02:51:38 AM  40.735531          -74.063365
# 501  2015-09-27 02:52:16 AM  40.743000          -73.935610
# 502  2015-09-27 02:50:32 AM  40.685160          -73.977114
# 503  2015-09-27 02:52:12 AM  40.758997          -73.968654
# 504  2015-09-27 02:49:31 AM  40.739974          -74.005139
# 505  2015-09-27 02:50:03 AM  40.723659          -74.064194
# 506  1969-12-31 07:00:00 PM  40.782750          -73.971370
# 507  1969-12-31 07:00:00 PM  40.680618          -73.946249
# 508  2015-09-27 02:49:45 AM  40.767801          -73.965921
#
#                                    stAddress1 stAddress2  \
# 0                            W 52 St & 11 Ave
# 1                    Franklin St & W Broadway
# 2                      St James Pl & Pearl St
# 3               Atlantic Ave & Fort Greene Pl
# 4                             W 17 St & 8 Ave
# 5                    Park Ave & St Edwards St
# 6                 Lexington Ave & Classon Ave
# 7                       Barrow St & Hudson St
# 8                    MacDougal St & Prince St
# 9                       E 56 St & Madison Ave
# 10                  Clinton St & Joralemon St
# 11                        Nassau St & Navy St
# 12                       Hudson St & Reade St
# 13                   Greenwich St & Warren St
# 14                          E 2 St & Avenue C
# 15                   Cleveland Pl & Spring St
# 16                      Warren St & Church St
# 17                            E 40 St & 5 Ave
# 18                    Henry St & Atlantic Ave
# 19                    E 37 St & Lexington Ave
# 20                      LaGuardia Pl & W 3 St
# 21                            E 47 St & 2 Ave
# 22                            E 39 St & 3 Ave
# 23                            W 18 St & 6 Ave
# 24                         Broadway & W 49 St
# 25                            E 25 St & 1 Ave
# 26                      Liberty St & Broadway
# 27                    W 16 St & The High Line
# 28            Columbia Heights & Cranberry St
# 29                              Old Fulton St
# ..                                        ...        ...
# 479                                   Sip Ave
# 480                            Riverview Park
# 481                                  North St
# 482                          Heights Elevator
# 483                              Newport Pkwy
# 484                            MLK Light Rail
# 485                                    Dey St
# 486                              Newport PATH
# 487                             Hamilton Park
# 488                         JC Medical Center
# 489                                   Hilltop
# 490                               Oakland Ave
# 491                              Brunswick St
# 492                            Pershing Field
# 493                                Newark Ave
# 494                           Christ Hospital
# 495                            Van Vorst Park
# 496                          Essex Light Rail
# 497                               Central Ave
# 498                             Columbia Park
# 499                              Bayside Park
# 500                         5 Corners Library
# 501                            47 Ave & 31 St
# 502                   Hanson Pl & St Felix St
# 503                           E 55 St & 3 Ave
# 504                       W 13 St & Hudson St
# 505                     Baldwin at Montgomery
# 506  Coming soon: W 82 St & Central Park West
# 507                 Marcy Ave & MacDonough St
# 508                        E 67 St & Park Ave
#
#                                   stationName  statusKey     statusValue  \
# 0                            W 52 St & 11 Ave          1      In Service
# 1                    Franklin St & W Broadway          1      In Service
# 2                      St James Pl & Pearl St          1      In Service
# 3               Atlantic Ave & Fort Greene Pl          1      In Service
# 4                             W 17 St & 8 Ave          1      In Service
# 5                    Park Ave & St Edwards St          1      In Service
# 6                 Lexington Ave & Classon Ave          1      In Service
# 7                       Barrow St & Hudson St          1      In Service
# 8                    MacDougal St & Prince St          3  Not In Service
# 9                       E 56 St & Madison Ave          1      In Service
# 10                  Clinton St & Joralemon St          1      In Service
# 11                        Nassau St & Navy St          1      In Service
# 12                       Hudson St & Reade St          1      In Service
# 13                   Greenwich St & Warren St          1      In Service
# 14                          E 2 St & Avenue C          1      In Service
# 15                   Cleveland Pl & Spring St          1      In Service
# 16                      Warren St & Church St          1      In Service
# 17                            E 40 St & 5 Ave          3  Not In Service
# 18                    Henry St & Atlantic Ave          1      In Service
# 19                    E 37 St & Lexington Ave          1      In Service
# 20                      LaGuardia Pl & W 3 St          1      In Service
# 21                            E 47 St & 2 Ave          1      In Service
# 22                            E 39 St & 3 Ave          1      In Service
# 23                            W 18 St & 6 Ave          1      In Service
# 24                         Broadway & W 49 St          1      In Service
# 25                            E 25 St & 1 Ave          1      In Service
# 26                      Liberty St & Broadway          3  Not In Service
# 27                    W 16 St & The High Line          1      In Service
# 28            Columbia Heights & Cranberry St          1      In Service
# 29                              Old Fulton St          1      In Service
# ..                                        ...        ...             ...
# 479                                   Sip Ave          1      In Service
# 480                            Riverview Park          1      In Service
# 481                                  North St          1      In Service
# 482                          Heights Elevator          1      In Service
# 483                              Newport Pkwy          1      In Service
# 484                            MLK Light Rail          1      In Service
# 485                                    Dey St          1      In Service
# 486                              Newport PATH          1      In Service
# 487                             Hamilton Park          1      In Service
# 488                         JC Medical Center          1      In Service
# 489                                   Hilltop          1      In Service
# 490                               Oakland Ave          1      In Service
# 491                              Brunswick St          1      In Service
# 492                            Pershing Field          1      In Service
# 493                                Newark Ave          1      In Service
# 494                           Christ Hospital          1      In Service
# 495                            Van Vorst Park          1      In Service
# 496                          Essex Light Rail          1      In Service
# 497                               Central Ave          1      In Service
# 498                             Columbia Park          1      In Service
# 499                              Bayside Park          1      In Service
# 500                         5 Corners Library          1      In Service
# 501                            47 Ave & 31 St          1      In Service
# 502                   Hanson Pl & St Felix St          1      In Service
# 503                           E 55 St & 3 Ave          1      In Service
# 504                       W 13 St & Hudson St          1      In Service
# 505                     Baldwin at Montgomery          1      In Service
# 506  Coming soon: W 82 St & Central Park West          3  Not In Service
# 507                 Marcy Ave & MacDonough St          3  Not In Service
# 508                        E 67 St & Park Ave          1      In Service
#
#     testStation  totalDocks
# 0         False          39
# 1         False          33
# 2         False          27
# 3         False          62
# 4         False          39
# 5         False          19
# 6         False          19
# 7         False          31
# 8         False          30
# 9         False          46
# 10        False          24
# 11        False          19
# 12        False          39
# 13        False          33
# 14        False          31
# 15        False          33
# 16        False          29
# 17        False          55
# 18        False          23
# 19        False          26
# 20        False          35
# 21        False          47
# 22        False          45
# 23        False          47
# 24        False          51
# 25        False          30
# 26        False          45
# 27        False          28
# 28        False          23
# 29        False          39
# ..          ...         ...
# 479       False          34
# 480       False          18
# 481       False          18
# 482       False          18
# 483       False          14
# 484       False          18
# 485       False          18
# 486       False          18
# 487       False          26
# 488       False          22
# 489       False          26
# 490       False          14
# 491       False          18
# 492       False          18
# 493       False          22
# 494       False          22
# 495       False          22
# 496       False          22
# 497       False          18
# 498       False          18
# 499       False          18
# 500       False          18
# 501       False          27
# 502       False          39
# 503       False          55
# 504       False          39
# 505       False          14
# 506       False           0
# 507       False           0
# 508       False          59
#
# [509 rows x 18 columns]

# %%
# available bikes

df['availableBikes'].hist()
plt.show()

# %%
# total docks

df['totalDocks'].hist()
plt.show()

# %%
# mean of stations that are active 

condition = (df["statusValue"] == "In Service")
df[condition]["totalDocks"].mean()
# Out:
# 32.692796610169495

# %%
# median of stations that are active; alternative syntax to above 

df[df["statusValue"] == "In Service"]["totalDocks"].median()
# Out:
# 31.0

# %%
# store data into SQLite
# create table for available stations

con = lite.connect("citi_bike.db")
cur = con.cursor()

with con: 
    cur.execute("CREATE TABLE citibike_reference (id INT PRIMARY KEY, totalDocks INT, city TEXT, altitude INT, stAddress2 TEXT, longitude NUMERIC, postalCode TEXT, testStation TEXT, stAddress1 TEXT, stationName TEXT, landMark TEXT, latitude NUMERIC, location TEXT)")

# parameterized query
sql = "INSERT INTO citibike_reference (id, totalDocks, city, altitude, stAddress2, longitude, postalCode, testStation, stAddress1, stationName, landMark, latitude, location) VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?)"

with con: 
    for station in r.json()["stationBeanList"]: 
        cur.execute(sql, (station["id"],station["totalDocks"],station["city"],station["altitude"],station["stAddress2"],station["longitude"],station["postalCode"],station["testStation"],station["stAddress1"],station["stationName"],station["landMark"],station["latitude"],station["location"]))

# %%
# create table for available bikes 

station_ids = df["id"].tolist()
station_ids = ["_" + str(x) + " INT" for x in station_ids]

with con: 
    cur.execute("CREATE TABLE available_bikes ( execution_time INT, " + ", ".join(station_ids) + ");")

# %%
# take execution time string and parse into Python datetime object 
# insert into database

# exec_time = parse(r.json()["executionTime"])

# with con: 
#     cur.execute("INSERT into available_bikes (execution_time) VALUES (?)", (exec_time.strftime("%s"),))

# %%
# use defaultdict to store available bikes by station id (i.e. station id: number of bikes available)

# id_bikes = collections.defaultdict(int)

# for station in r.json()["stationBeanList"]: 
#     id_bikes[station["id"]] = station["availableBikes"]

# with con: 
#     for k, v in id_bikes.iteritems(): 
#         cur.execute("UPDATE available_bikes SET _" + str(k) + " = " + str(v) + " WHERE execution_time = " + exec_time.strftime("%s") + ";")

# %%
con = lite.connect("citi_bike.db")
cur = con.cursor()

for i in range(60): 
    r = requests.get("http://www.citibikenyc.com/stations/json")
    exec_time = parse(r.json()["executionTime"])  
    
    cur.execute("INSERT INTO available_bikes(execution_time) VALUES (?)", (exec_time.strftime("%s"),))
    con.commit()
    
    # create dictionary of station id and available bikes
    id_bikes = collections.defaultdict(int)
    for station in r.json()["stationBeanList"]: 
        id_bikes[station["id"]] = station["availableBikes"]
    
    # loop through id_bikes dictionary 
    for station_id, avail_bikes in id_bikes.iteritems(): 
    #   print k, v
        cur.execute("UPDATE available_bikes SET _" + str(station_id) + " = " + str(avail_bikes) + " WHERE execution_time = " + exec_time.strftime('%s') + ";")
    
    # pause the program for 60 seconds  
    time.sleep(60)

con.close()

# %% [markdown]
# <h6> Analyze the results</h6>

# %%
con = lite.connect("citi_bike.db")
cur = con.cursor() 

print(con)

def get_bikes():
    cur.execute("SELECT * FROM available_bikes")
    print(cur.fetchall())

get_bikes()

# df = pd.read_sql_query("SELECT * FROM available_bikes")

# df = pd.read_sql_query("SELECT * FROM available_bikes ORDER BY execution_time",con,index_col="execution_time")
